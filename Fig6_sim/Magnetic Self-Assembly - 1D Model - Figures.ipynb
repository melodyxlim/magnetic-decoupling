# %%
import numpy as np
from tqdm import tqdm, trange

import pickle

import matplotlib.pyplot as plt

plt.rcParams.update({"font.size": 15})

# %% [markdown]
# # QUENCHING

# %%
with open("figs/fig_quench_yields_T.pkl", "rb") as f:
    fig_quench = pickle.load(f)

# %%
# fig_quench.savefig("figs/PDF/fig_quench_yields_T.pdf", bbox_inches="tight")

# %% [markdown]
# # MELTING

# %%
with open("figs/fig_melt_yields_T.pkl", "rb") as f:
    fig_melt = pickle.load(f)

# %%
# fig_melt.savefig("figs/PDF/fig_melt_yields_T.pdf", bbox_inches="tight")

# %% [markdown]
# # CYCLING

# %%
with open("figs/fig_cycling_single_tetram_cmp.pkl", "rb") as f:
    fig_cycling = pickle.load(f)

# %%
# fig_cycling.savefig("figs/PDF/fig_cycling_single_tetram_cmp.pdf", bbox_inches="tight")
